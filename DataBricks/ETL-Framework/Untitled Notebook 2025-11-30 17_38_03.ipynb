# %%
display(dbutils.fs.ls("/FileStore"))

# %%
# show first 20 chars of the file
print(open("/dbfs/FileStore/utils_etl.py", "r").read(200))

# %%
import sys
print("/dbfs/FileStore" in sys.path)
print(sys.path[:10])

# %%
display(dbutils.fs.ls("/FileStore"))

# %%
module_code = """<paste the exact contents of utils_etl.py above>"""
dbutils.fs.put("/FileStore/utils_etl.py", module_code, True)

# %%
import sys
if "/dbfs/FileStore" not in sys.path:
    sys.path.insert(0, "/dbfs/FileStore")
import importlib, utils_etl
importlib.reload(utils_etl)

# %%
display(dbutils.fs.ls("/FileStore"))

# %%
import sys
if "/dbfs/FileStore" not in sys.path:
    sys.path.insert(0, "/dbfs/FileStore")

import importlib
import utils_etl
importlib.reload(utils_etl)

print("utils_etl imported successfully!")
